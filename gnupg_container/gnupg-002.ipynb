# %%
import os
import shutil

import gnupg

# %%
gpgdir = f"{os.getcwd()}/gpg"

gpgdir
# Out:
# '/data/data/com.termux/files/home/git-stuff/jupyter-etudes/gnupg_container/gpg'

# %%
shutil.rmtree(gpgdir)
os.mkdir(gpgdir)

# %%
gpg = gnupg.GPG(gnupghome=gpgdir)
gpg.encoding = "utf-8"

gpg

# %%
input_data = gpg.gen_key_input(key_type="RSA", key_length=2048, no_protection=True)

master_key = gpg.gen_key(input_data)

# %%
subkey = gpg.add_subkey(master_key.fingerprint, "")

# %%
master_key.fingerprint
# Out:
# 'DC1E92B57A5C0029B326EB8C7AFF44B50B5F9F15'

# %%
gpg.list_keys(True)
# Out:
# [{'type': 'sec',
#   'trust': 'u',
#   'length': '2048',
#   'algo': '1',
#   'keyid': '7AFF44B50B5F9F15',
#   'date': '1752215064',
#   'expires': '',
#   'dummy': '',
#   'ownertrust': 'u',
#   'sig': '',
#   'cap': 'escarESCA',
#   'issuer': '',
#   'flag': '',
#   'token': '+',
#   'hash': '',
#   'curve': '',
#   'compliance': '23',
#   'updated': '',
#   'origin': '0',
#   'keygrip': 'BBE2EFF477C355706D5D578DFDA069B130DF315D',
#   'uids': ['Autogenerated Key <u0_a333@localhost>'],
#   'sigs': [],
#   'subkeys': [['1C9EB79364C308CC',
#     None,
#     'FD228546FB854ED4322B937B1C9EB79364C308CC',
#     '4B53E9D5E478CA83BAA0A6D60018F015606D5324']],
#   'fingerprint': 'DC1E92B57A5C0029B326EB8C7AFF44B50B5F9F15',
#   'subkey_info': {'1C9EB79364C308CC': {'type': 'ssb',
#     'trust': 'u',
#     'length': '3072',
#     'algo': '1',
#     'keyid': '1C9EB79364C308CC',
#     'date': '1752215064',
#     'expires': '',
#     'dummy': '',
#     'ownertrust': '',
#     'uid': '',
#     'sig': '',
#     'cap': 'e',
#     'issuer': '',
#     'flag': '',
#     'token': '+',
#     'hash': '',
#     'curve': '',
#     'compliance': '23',
#     'updated': '',
#     'origin': 'unavailable',
#     'keygrip': 'unavailable'}}}]
